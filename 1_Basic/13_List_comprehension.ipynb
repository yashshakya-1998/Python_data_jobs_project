# %% [markdown]
# ## List Comprehension

# %%
job_titles = [
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Business Intelligence Analyst",
    "Machine Learning Engineer",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Analytics Consultant",
    "Data Analyst",
    "ETL Developer",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "AI Engineer",
    "Data Analyst",
    "Business Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Data Engineer",
    "Data Analyst",
    "Machine Learning Engineer",
    "Data Scientist",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Data Architect",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Business Intelligence Analyst",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "AI Engineer",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "ETL Developer",
    "Data Engineer",
    "Data Analyst",
    "Data Scientist",
    "Data Analyst",
    "Machine Learning Engineer",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Business Analyst",
    "Data Engineer",
    "Data Analyst",
    "Data Scientist",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Analytics Consultant",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "AI Engineer",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Business Intelligence Analyst",
    "Data Engineer",
    "Data Analyst",
    "Data Scientist",
    "Data Analyst",
    "Machine Learning Engineer",
    "Data Engineer",
    "Data Analyst",
    "Data Scientist",
    "Data Analyst",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Data Architect",
    "Data Engineer",
    "Data Analyst",
    "Data Scientist",
    "Data Analyst",
    "ETL Developer",
    "Data Engineer",
    "Data Analyst",
    "Data Scientist",
    "Data Analyst"
]

# %%
len(job_titles)
# Out:
# 98

# %%
analyst_list=[]
for job in job_titles:
  if job == "Data Analyst":
    analyst_list.append(job)
len(analyst_list)
# Out:
# 37

# %%
# Using List Comprehension
analyst_list = [job for job in job_titles if job == "Data Analyst"]
len(analyst_list)
# Out:
# 37
