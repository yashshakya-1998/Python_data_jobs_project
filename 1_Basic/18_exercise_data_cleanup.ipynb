# %%
job_roles = [
    {'role': 'Data Analyst',
     'skills': "['Python', 'SQL', 'Excel']",
     'job_date': '2024-03-15'},

    {'role': 'Data Scientist',
     'skills': "['Python', 'R', 'Machine Learning', 'Deep Learning']",
     'job_date': '2023-11-08'},

    {'role': 'Machine Learning Engineer',
     'skills': "['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']",
     'job_date': '2024-01-22'},

    {'role': 'Data Engineer',
     'skills': "['Python', 'Apache Spark', 'Hadoop', 'SQL']",
     'job_date': '2023-09-30'},

    {'role': 'Business Intelligence Analyst',
     'skills': "['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']",
     'job_date': '2024-02-10'},

    {'role': 'Quantitative Analyst',
     'skills': "['R', 'Python', 'MATLAB', 'Statistics']",
     'job_date': '2023-12-19'},

    {'role': 'Operations Analyst',
     'skills': "['Python', 'SQL', 'Data Visualization', 'Process Improvement']",
     'job_date': '2024-04-05'},

    {'role': 'Database Administrator',
     'skills': "['SQL', 'Oracle', 'MySQL', 'Database Management']",
     'job_date': '2023-10-27'},

    {'role': 'AI Engineer',
     'skills': "['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']",
     'job_date': '2024-05-14'},

    {'role': 'Statistician',
     'skills': "['R', 'SAS', 'Python', 'Statistical Modeling']",
     'job_date': '2023-08-21'}
]

# %%
from datetime import datetime

test_date = job_roles[0]['job_date']
print(datetime.strptime(test_date, "%Y-%m-%d"))
# Out:
# 2024-03-15 00:00:00

# %%
import ast
for job in job_roles:
    job['job_date'] = datetime.strptime(job['job_date'], "%Y-%m-%d")
    job['skills'] = ast.literal_eval(job['skills'])

# %%
job_roles
# Out:
# [{'role': 'Data Analyst',
#   'skills': ['Python', 'SQL', 'Excel'],
#   'job_date': datetime.datetime(2024, 3, 15, 0, 0)},
#  {'role': 'Data Scientist',
#   'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning'],
#   'job_date': datetime.datetime(2023, 11, 8, 0, 0)},
#  {'role': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn'],
#   'job_date': datetime.datetime(2024, 1, 22, 0, 0)},
#  {'role': 'Data Engineer',
#   'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL'],
#   'job_date': datetime.datetime(2023, 9, 30, 0, 0)},
#  {'role': 'Business Intelligence Analyst',
#   'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel'],
#   'job_date': datetime.datetime(2024, 2, 10, 0, 0)},
#  {'role': 'Quantitative Analyst',
#   'skills': ['R', 'Python', 'MATLAB', 'Statistics'],
#   'job_date': datetime.datetime(2023, 12, 19, 0, 0)},
#  {'role': 'Operations Analyst',
#   'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement'],
#   'job_date': datetime.datetime(2024, 4, 5, 0, 0)},
#  {'role': 'Database Administrator',
#   'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management'],
#   'job_date': datetime.datetime(2023, 10, 27, 0, 0)},
#  {'role': 'AI Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision'],
#   'job_date': datetime.datetime(2024, 5, 14, 0, 0)},
#  {'role': 'Statistician',
#   'skills': ['R', 'SAS', 'Python', 'Statistical Modeling'],
#   'job_date': datetime.datetime(2023, 8, 21, 0, 0)}]
