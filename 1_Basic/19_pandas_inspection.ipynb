# %%
# !pip install datasets

# %%
from datasets import load_dataset

df = load_dataset("lukebarousse/data_jobs")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
import pandas as pd

# Convert the dataset split to a pandas DataFrame
df = df['train'].to_pandas()

# Now you can use .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df[['job_title_short', 'job_skills']].head()
# Out:
#         job_title_short                                         job_skills
# 0  Senior Data Engineer                                               None
# 1          Data Analyst  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2         Data Engineer  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3         Data Engineer  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4         Data Engineer  ['bash', 'python', 'oracle', 'aws', 'ansible',...

# %%
# Using .iloc to select row index 5 and only first 5 columns
df[['job_title_short', 'job_via']].iloc[90:100]
# Out:
#          job_title_short                         job_via
# 90        Data Scientist             via BeBee Australia
# 91        Data Scientist                 via BeBee Chile
# 92         Data Engineer                    via LinkedIn
# 93          Data Analyst                    via LinkedIn
# 94         Data Engineer                    via LinkedIn
# 95         Data Engineer  via Crimsoniteam.freshteam.com
# 96         Data Engineer                    via LinkedIn
# 97          Data Analyst                   via Totaljobs
# 98  Senior Data Engineer  via SmartRecruiters Job Search
# 99         Data Engineer                    via LinkedIn

# %%
df

# %%
# Filter for Data Analyst roles where salary_year_avg is not NaN
df_data_analyst = df[(df['job_title_short'] == "Data Analyst") & (df['salary_year_avg'].notna())]

# Display the filtered dataframe
df_data_analyst
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
# Get the number of unique values in job_title_short
unique_titles_count = df['job_title_short'].nunique()
print(f"Total unique job titles: {unique_titles_count}")

# Optionally, display the specific counts for each unique title
display(df['job_title_short'].value_counts())
# Out:
# Total unique job titles: 10
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Set black background
ax = plt.gca()
ax.set_facecolor('black')
plt.gcf().set_facecolor('black')

# Sort descending (largest to smallest)
df_job_counts = df_job_counts.sort_values('job_count', ascending=False)

# Create the bar chart with a Blue gradient palette and no borders (linewidth=0)
sns.barplot(data=df_job_counts, x='job_count', y='job_title_short', palette='Blues_r', hue='job_title_short', legend=False, linewidth=0)

# Add titles and labels with white text for visibility
plt.title('Which are the most trending data jobs?', color='white', fontsize=16)
plt.xlabel('Job count', color='white')
plt.ylabel('Job Title', color='white')
plt.xticks(color='white')
plt.yticks(color='white')

# Remove grid or make it subtle
plt.grid(True, axis='x', linestyle='--', alpha=0.3)

# Show the plot
plt.show()

# %%
# Get value counts and rename the count column to job_count
df_job_counts = df['job_title_short'].value_counts().reset_index()
df_job_counts.columns = ['job_title_short', 'job_count']

# Display the resulting DataFrame
display(df_job_counts)
# Out:
#              job_title_short  job_count
# 0               Data Analyst     196075
# 1              Data Engineer     186241
# 2             Data Scientist     172286
# 3           Business Analyst      49063
# 4          Software Engineer      44929
# 5       Senior Data Engineer      44563
# 6      Senior Data Scientist      36957
# 7        Senior Data Analyst      29216
# 8  Machine Learning Engineer      14080
# 9             Cloud Engineer      12331
