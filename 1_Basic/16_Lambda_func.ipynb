# %% [markdown]
# ## User defined functions

# %%
base_salary = 120000
bonus_rate = 0.15
def calc_salary():
  total_salary = base_salary * (1 + bonus_rate)
  return total_salary
calc_salary()
# Out:
# 138000.0

# %% [markdown]
# ## Lambda

# %%
salary_list = [120000, 20000, 50000, 99900, 55500, 125000, 100000, 920000]
bonus_rate = 0.10
new_salaries = [(lambda x: x * 1.1)(salary) for salary in salary_list]
new_salaries
# Out:
# [132000.0,
#  22000.0,
#  55000.00000000001,
#  109890.00000000001,
#  61050.00000000001,
#  137500.0,
#  110000.00000000001,
#  1012000.0000000001]

# %%
job_roles = [
    {'role': 'Data Analyst',
     'skills': ['Python', 'SQL', 'Excel'],
     'WFH': True},

    {'role': 'Data Scientist',
     'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning'],
     'WFH': False},

    {'role': 'Machine Learning Engineer',
     'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn'],
     'WFH': True},

    {'role': 'Data Engineer',
     'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL'],
     'WFH': False},

    {'role': 'Business Intelligence Analyst',
     'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel'],
     'WFH': True},

    {'role': 'Quantitative Analyst',
     'skills': ['R', 'Python', 'MATLAB', 'Statistics'],
     'WFH': False},

    {'role': 'Operations Analyst',
     'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement'],
     'WFH': True},

    {'role': 'Database Administrator',
     'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management'],
     'WFH': False},

    {'role': 'AI Engineer',
     'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision'],
     'WFH': True},

    {'role': 'Statistician',
     'skills': ['R', 'SAS', 'Python', 'Statistical Modeling'],
     'WFH': False}
]

# %%
list(filter(lambda job: job['WFH'] and 'Python' in job['skills'], job_roles))
# Out:
# [{'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel'], 'WFH': True},
#  {'role': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn'],
#   'WFH': True},
#  {'role': 'Business Intelligence Analyst',
#   'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel'],
#   'WFH': True},
#  {'role': 'Operations Analyst',
#   'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement'],
#   'WFH': True},
#  {'role': 'AI Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision'],
#   'WFH': True}]
